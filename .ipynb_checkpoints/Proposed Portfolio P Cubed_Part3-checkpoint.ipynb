# %%
#Initial Imports
import pandas as pd
import numpy as np
import datetime as dt
from pathlib import Path

# %matplotlib inline

# %%
#Read the AAPL.csv data files
aapl_csv = Path("Resources/aapl.csv")
aapl =pd.read_csv(aapl_csv, index_col="Date", parse_dates=True, infer_datetime_format=True)
aapl = aapl.rename(columns={"Close":"aapl"})
aapl = aapl[["aapl"]]
aapl
# Out:
#                   aapl
# Date
# 2016-10-13   29.245001
# 2016-10-14   29.407499
# 2016-10-17   29.387501
# 2016-10-18   29.367500
# 2016-10-19   29.280001
# ...                ...
# 2021-10-06  142.000000
# 2021-10-07  143.289993
# 2021-10-08  142.899994
# 2021-10-11  142.809998
# 2021-10-12  141.509995
#
# [1258 rows x 1 columns]

# %%
#Count Nulls
print(aapl.isnull().sum())
print(aapl[aapl.isnull().any(axis = 1)])
# Out:
# aapl    0
# dtype: int64
# Empty DataFrame
# Columns: [aapl]
# Index: []

# %%
#Drop nulls
aapl.dropna(inplace=True)

# %%
#Read the goog.csv data files
goog_csv = Path("Resources/goog.csv")
goog =pd.read_csv(goog_csv, index_col="Date", parse_dates=True, infer_datetime_format=True)
goog = goog.rename(columns={"Close":"goog"})
goog = goog[["goog"]]
goog
# Out:
#                    goog
# Date
# 2016-10-13   778.190002
# 2016-10-14   778.530029
# 2016-10-17   779.960022
# 2016-10-18   795.260010
# 2016-10-19   801.500000
# ...                 ...
# 2021-10-06  2747.080078
# 2021-10-07  2783.709961
# 2021-10-08  2801.120117
# 2021-10-11  2776.949951
# 2021-10-12  2734.260010
#
# [1258 rows x 1 columns]

# %%
#Count Nulls
print(goog.isnull().sum())
print(goog[goog.isnull().any(axis = 1)])
# Out:
# goog    0
# dtype: int64
# Empty DataFrame
# Columns: [goog]
# Index: []

# %%
#Drop nulls
goog.dropna(inplace=True)

# %%
#Read the nflx.csv data files
nflx_csv = Path("Resources/nflx.csv")
nflx =pd.read_csv(nflx_csv, index_col="Date", parse_dates=True, infer_datetime_format=True)
nflx = nflx.rename(columns={"Close":"nflx"})
nflx = nflx[["nflx"]]
nflx
# Out:
#                   nflx
# Date
# 2016-10-13  100.230003
# 2016-10-14  101.470001
# 2016-10-17   99.800003
# 2016-10-18  118.790001
# 2016-10-19  121.870003
# ...                ...
# 2021-10-06  639.099976
# 2021-10-07  631.849976
# 2021-10-08  632.659973
# 2021-10-11  627.039978
# 2021-10-12  624.940002
#
# [1258 rows x 1 columns]

# %%
#Count Nulls
print(nflx.isnull().sum())
print(nflx[nflx.isnull().any(axis = 1)])
# Out:
# nflx    0
# dtype: int64
# Empty DataFrame
# Columns: [nflx]
# Index: []

# %%
#Drop nulls
nflx.dropna(inplace=True)

# %%
#Read the nvda.csv data files
nvda_csv = Path("Resources/nvda.csv")
nvda =pd.read_csv(nvda_csv, index_col="Date", parse_dates=True, infer_datetime_format=True)
nvda = nvda.rename(columns={"Close":"nvda"})
nvda = nvda[["nvda"]]
nvda
# Out:
#                   nvda
# Date
# 2016-10-13   16.337500
# 2016-10-14   16.497499
# 2016-10-17   16.402500
# 2016-10-18   16.652500
# 2016-10-19   16.617500
# ...                ...
# 2021-10-06  207.000000
# 2021-10-07  210.750000
# 2021-10-08  208.309998
# 2021-10-11  206.949997
# 2021-10-12  206.710007
#
# [1258 rows x 1 columns]

# %%
#Count Nulls
print(nvda.isnull().sum())
print(nvda[nvda.isnull().any(axis = 1)])
# Out:
# nvda    0
# dtype: int64
# Empty DataFrame
# Columns: [nvda]
# Index: []

# %%
#Drop nulls
nvda.dropna(inplace=True)

# %%
# Join AAPL, GOOG, NFLX, and NVDA into a single Data Frame
df_daily = pd.concat([aapl,goog,nflx,nvda], axis = "columns", join = "inner")
df_daily_returns = df_daily.pct_change()
df_daily_returns = df_daily_returns.dropna().copy()
df_daily_returns
# Out:
#                 aapl      goog      nflx      nvda
# Date
# 2016-10-14  0.005556  0.000437  0.012372  0.009793
# 2016-10-17 -0.000680  0.001837 -0.016458 -0.005758
# 2016-10-18 -0.000681  0.019616  0.190281  0.015242
# 2016-10-19 -0.002979  0.007846  0.025928 -0.002102
# 2016-10-20 -0.000512 -0.005652  0.012144  0.018956
# ...              ...       ...       ...       ...
# 2021-10-06  0.006307  0.008643  0.006758  0.012175
# 2021-10-07  0.009084  0.013334 -0.011344  0.018116
# 2021-10-08 -0.002722  0.006254  0.001282 -0.011578
# 2021-10-11 -0.000630 -0.008629 -0.008883 -0.006529
# 2021-10-12 -0.009103 -0.015373 -0.003349 -0.001160
#
# [1257 rows x 4 columns]

# %%
# PLot daily returns of all portfolios
df_daily.plot(figsize = (20,10))
# Out:
# <AxesSubplot:xlabel='Date'>

# %% [raw]
# # Calculate cumulative returns of the the stocks
# df_cum = (1+ df_daily).cumprod()

# %%
df_cum = (1+ df_daily_returns).cumprod()

df_cum.replace([np.inf,-np.inf],np.nan,inplace=True)
df_cum = df_cum.dropna().copy()
df_cum
# Out:
#                 aapl      goog      nflx       nvda
# Date
# 2016-10-14  1.005556  1.000437  1.012372   1.009793
# 2016-10-17  1.004873  1.002275  0.995710   1.003979
# 2016-10-18  1.004189  1.021936  1.185174   1.019281
# 2016-10-19  1.001197  1.029954  1.215903   1.017138
# 2016-10-20  1.000684  1.024133  1.230669   1.036419
# ...              ...       ...       ...        ...
# 2021-10-06  4.855531  3.530089  6.376334  12.670237
# 2021-10-07  4.899641  3.577160  6.304000  12.899770
# 2021-10-08  4.886305  3.599532  6.312082  12.750421
# 2021-10-11  4.883228  3.568473  6.256011  12.667177
# 2021-10-12  4.838776  3.513615  6.235059  12.652487
#
# [1257 rows x 4 columns]

# %%
# Plot cumulative returns
df_cum.plot(figsize = (20,10))
# Out:
# <AxesSubplot:xlabel='Date'>

# %% [markdown]
#  <AxesSubplot:xlabel='Date'>

# %%
# Box plot to visually show risk
df_daily_returns.plot(kind = "box", figsize = (20,10))
# Out:
# <AxesSubplot:>

# %%
# Calculate the standard deviation of all stocks
#df_daily_std = pd.DataFrame(df_daily.std()).rename(columns - [0:"std"})
df_daily_returns.std()
# Out:
# aapl    0.019043
# goog    0.016909
# nflx    0.024573
# nvda    0.030348
# dtype: float64

# %%
# Calculate the Annualized Std Deviation (252 trading days)
df_annualized_std = df_daily_returns.std()*np.sqrt(252)
df_annualized_std
# Out:
# aapl    0.302294
# goog    0.268417
# nflx    0.390088
# nvda    0.481764
# dtype: float64

# %%
annualized_std_df = pd.DataFrame(df_annualized_std)
annualized_std_df = annualized_std_df.swapaxes("index", "columns")
annualized_std_df.plot(kind='bar')
# Out:
# <AxesSubplot:>

# %%
#add column to dataframe
annualized_std_df['test'] = 0.9999
annualized_std_df
# Out:
#        aapl      goog      nflx      nvda    test
# 0  0.302294  0.268417  0.390088  0.481764  0.9999
